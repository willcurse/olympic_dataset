# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style='whitegrid')

# %% [markdown]
# # 1: Data Collection

# %% [markdown]
# # 1.1 Data loading

# %%
data=pd.read_csv(r'C:\Users\Administrator\Desktop\DA-jupyter\olympics-economics.csv')
data
# Out:
#           country country_code  gold  silver  bronze  total       gdp  \
# 0   United States          USA    40      44      42    126  81695.19
# 1           China          CHN    40      27      24     91  12614.06
# 2           Japan          JPN    20      12      13     45  33834.39
# 3       Australia          AUS    18      19      16     53  64711.77
# 4          France          FRA    16      26      22     64  44460.82
# ..            ...          ...   ...     ...     ...    ...       ...
# 85           Peru          PER     0       0       1      1   7789.87
# 86          Qatar          QAT     0       0       1      1  87480.42
# 87      Singapore          SGP     0       0       1      1  84734.26
# 88       Slovakia          SVK     0       0       1      1  24470.24
# 89         Zambia          ZMB     0       0       1      1   1369.13
#
#     gdp_year  population
# 0       2023       334.9
# 1       2023      1410.7
# 2       2023       124.5
# ...

# %% [markdown]
# # 1.2 Null Data Checking

# %%
data.isnull().sum()
# Out:
# country         0
# country_code    0
# gold            0
# silver          0
# bronze          0
# total           0
# gdp             0
# gdp_year        0
# population      0
# dtype: int64

# %% [markdown]
# # 2: Data Cleaning

# %% [markdown]
# # 2.1: Data Information

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   country       90 non-null     object
#  1   country_code  90 non-null     object
#  2   gold          90 non-null     int64
#  3   silver        90 non-null     int64
#  4   bronze        90 non-null     int64
#  5   total         90 non-null     int64
#  6   gdp           90 non-null     float64
#  7   gdp_year      90 non-null     int64
#  8   population    90 non-null     float64
# dtypes: float64(2), int64(5), object(2)
# memory usage: 6.5+ KB

# %%
data.describe()
# Out:
#             gold     silver     bronze       total            gdp  \
# count  90.000000  90.000000  90.000000   90.000000      90.000000
# mean    3.644444   3.633333   4.255556   11.533333   24478.053556
# std     7.018933   6.797967   6.586607   19.782071   25547.857382
# min     0.000000   0.000000   0.000000    1.000000    1014.210000
# 25%     0.000000   0.000000   1.000000    2.000000    5815.180000
# 50%     1.000000   1.000000   2.000000    5.000000   13061.185000
# 75%     3.000000   3.000000   5.000000    9.000000   34484.677500
# max    40.000000  44.000000  42.000000  126.000000  103684.880000
#
#           gdp_year   population
# count    90.000000    90.000000
# mean   2022.977778    69.027778
# std       0.148231   213.286437
# min    2022.000000     0.100000
# 25%    2023.000000     5.325000
# 50%    2023.000000    12.150000
# 75%    2023.000000    48.550000
# max    2023.000000  1428.600000

# %% [markdown]
# # 3: Data Analysis

# %%
data.columns
# Out:
# Index(['country', 'country_code', 'gold', 'silver', 'bronze', 'total', 'gdp',
#        'gdp_year', 'population'],
#       dtype='object')

# %% [markdown]
# # 1. Which country won the most total medals?

# %%
max_medal=data.loc[data['total'].idxmax(),['country','total']]
max_medal
# Out:
# country    United States
# total                126
# Name: 0, dtype: object

# %% [markdown]
# # 2: Top 10 country for medal

# %%
top_10=data.sort_values(by='total',ascending=False).head(10)

plt.figure(figsize=(10, 6))  
sns.barplot(x='total', y='country', data=top_10)
plt.title('Top 10 Countries by Total Medals')
plt.show()

# %% [markdown]
# # 3: Which country has the highest GDP?

# %%
data.columns
# Out:
# Index(['country', 'country_code', 'gold', 'silver', 'bronze', 'total', 'gdp',
#        'gdp_year', 'population'],
#       dtype='object')

# %%
highest_gdp=data.loc[data['gdp'].idxmax(),['country','gdp']]
print(highest_gdp)
# Out:
# country      Ireland
# gdp        103684.88
# Name: 18, dtype: object

# %% [markdown]
# # 4: Top 10 countries..according to GDP

# %%
top_10=data.sort_values(by='gdp',ascending=False).head(10)

plt.figure(figsize=(10,6))
sns.barplot(x='gdp',y='country',data=top_10)
plt.title('Top 10 countries')
plt.show()

# %% [markdown]
# # 5:  Which country has the largest population?

# %%
highest_pop=data.loc[data['population'].idxmax(),['country','population']]
print(highest_pop)
# Out:
# country        India
# population    1428.6
# Name: 70, dtype: object

# %% [markdown]
# # 6: Top 10 largest population country

# %%
top_pop=data.sort_values(by='population',ascending=False).head(10)

plt.figure(figsize=(10,6))
sns.barplot(x='population',y='country',data=top_pop)
plt.title('top 10 largest population country')
plt.show()

# %% [markdown]
# # 7: Which country won the most gold medals?

# %%
data.columns
# Out:
# Index(['country', 'country_code', 'gold', 'silver', 'bronze', 'total', 'gdp',
#        'gdp_year', 'population'],
#       dtype='object')

# %%
most_gold=data.loc[data['gold'].idxmax(),['country','gold']]
print(most_gold)
# Out:
# country    United States
# gold                  40
# Name: 0, dtype: object

# %% [markdown]
# # 8: Top 10 country with gold medals?

# %%
top_10=data.sort_values(by='gold',ascending=False).head(10)

plt.figure(figsize=(10,6))
sns.barplot(x='gold',y='country',data=top_10)
plt.title('Top 10 country with gold medals?')
plt.show()

# %% [markdown]
# # 9:  What is the average number of total medals won by the countries?

# %%
data.columns
# Out:
# Index(['country', 'country_code', 'gold', 'silver', 'bronze', 'total', 'gdp',
#        'gdp_year', 'population'],
#       dtype='object')

# %%
average_medal=data[['total']].mean()
print(f'The average number of total medal won by countries are: {average_medal} ')
# Out:
# The average number of total medal won by countries are: total    11.533333
# dtype: float64

# %% [markdown]
# # 10: Is there a correlation between GDP and the total number of medals?

# %%
correlation=data['gdp'].corr(data['total'])
print(correlation)
# Out:
# 0.34794157444147733

# %% [markdown]
# # 11: What percentage of total medals did the United States win?

# %%
# medal won by u.s
us_medal=data.loc[data['country']=='United States','total'].values[0]

total_medal=data['total'].sum()

percentage_of_medal=(us_medal/total_medal)*100
print(f' percentage of total medals did the United States win are {percentage_of_medal}')
# Out:
#  percentage of total medals did the United States win are 12.138728323699421

# %% [markdown]
# # 12: Which country has the lowest population but still won medals?

# %%
medal_winner=data[data['total']>0]
low_pop=medal_winner.loc[medal_winner['population'].idxmin()]
print(low_pop)
# Out:
# country         Dominica
# country_code         DMA
# gold                   1
# silver                 0
# bronze                 0
# total                  1
# gdp               8953.9
# gdp_year            2023
# population           0.1
# Name: 61, dtype: object

# %% [markdown]
# # 13: Lowest 10 Population countries?..

# %%
low_pop=data.sort_values(by='population',ascending=True).head(10)

plt.figure(figsize=(10,6))
sns.barplot(x='population',y='country',data=low_pop)
plt.title(' Lowest 10 Population countries?..')
plt.show()

# %% [markdown]
# # 14: What is the total population of countries that won more than 50 medals?

# %%
total_medal=data[data['total']>50]

total_pop=total_medal['population'].sum().round()
print(f'the total population of countries that won more than 50 medals are {total_pop}')
# Out:
# the total population of countries that won more than 50 medals are 1909.0

# %% [markdown]
# # 15: Top population of countries that won more than 50 medals..?

# %%
total_medal=data[data['total']>50]
plt.figure(figsize=(10,6))
sns.barplot(x='population',y='country',data=total_medal)
plt.title('Top population of countries that won more than 50 medals..?')
plt.show()

# %% [markdown]
# # 16: Which country has the highest medals-to-population ratio?

# %%
data.columns
# Out:
# Index(['country', 'country_code', 'gold', 'silver', 'bronze', 'total', 'gdp',
#        'gdp_year', 'population'],
#       dtype='object')

# %%
data['mean_to_population']=data['total']/data['population']

# %%
data.columns
# Out:
# Index(['country', 'country_code', 'gold', 'silver', 'bronze', 'total', 'gdp',
#        'gdp_year', 'population', 'mean_to_population'],
#       dtype='object')

# %%
highest_medal_to_pop=data.loc[data['mean_to_population'].idxmax()]
print(highest_medal_to_pop[['country', 'population', 'total', 'mean_to_population']])
# Out:
# country               Grenada
# population                0.1
# total                       2
# mean_to_population       20.0
# Name: 80, dtype: object

# %% [markdown]
# # 17: Visualizing Medal Counts

# %%
medal_types = ['gold', 'silver', 'bronze']
data[medal_types].sum().plot(kind='bar', color=['gold', 'silver', '#cd7f32'])
plt.title('Total Medal Counts by Type')
plt.ylabel('Number of Medals')
plt.show()

# %% [markdown]
# # 18: Population vs. Total Medals

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x='population', y='total', hue='country', legend=False)
plt.title('Population vs. Total Medals')
plt.xlabel('Population (in millions)')
plt.ylabel('Total Medals')
plt.xscale('log')
plt.show()
